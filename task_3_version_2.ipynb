# %% [markdown]
# # Задание 3

# %% [markdown]
# В игре Plants & Gardens каждый месяц проводятся тематические события, ограниченные по времени. В них игроки могут получить уникальные предметы для сада и персонажей, дополнительные монеты или бонусы. Для получения награды требуется пройти ряд уровней за определенное время. С помощью каких метрик можно оценить результаты последнего прошедшего события?
#
# Предположим, в другом событии мы усложнили механику событий так, что при каждой неудачной попытке выполнения уровня игрок будет откатываться на несколько уровней назад. Изменится ли набор метрик оценки результата? Если да, то как?

# %% [markdown]
# # С помощью каких метрик можно оценить результаты последнего прошедшего события?
#
# - Retention (возврат старых игроков, которые ранее были не активны, в разный временной промежуток)
# - доля реактивированных игроков (которые вернулись, по каким-то причинам)
# - MAU/DAU/WAU - кол-во уникальных игроков за месяц/день/неделю
# - ARPDAU (повышение средних чеков у активных игроков в дни проведения событий)
# - LTV (сезонные события, которые могут увеличить средний LTV пользователей, проходя которые люди могут получить особенные награды и т.д., потратив реальные деньги на покупки в игре)
# - Churn Rate (процент оттока после проведения события, в течение какого-то кол-ва дней)
# - Session Time (кол-во и средняя продолжительность нахождения в игре во время события).

# %% [markdown]
# # Предположим, в другом событии мы усложнили механику событий так, что при каждой неудачной попытке выполнения уровня игрок будет откатываться на несколько уровней назад. Изменится ли набор метрик оценки результата? Если да, то как?

# %% [markdown]
# Метрики значительно не поменяются, но я думаю такое решение, вероятно, приведет к оттоку пользователей, т.к. им будет невыгодно и неинтересно терять прогресс за уже купленные ими предметы в игре и заново проходить одни и те же уровни. В таком случае, стоит обратить внимание на метрики Session Time и Churn Rate, а также на время прохождение каждого уровня. Если же усложненная механика будет предполагать покупки уникальных предметов, то необходимо отследить изменения в метриках revenue и ARPU до и после изменений. Если churn rate растет, а revenue и ARPU падают, то скорее всего нужно менять стратегию.
